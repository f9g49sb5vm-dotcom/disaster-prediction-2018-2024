# %% [markdown]
# # Phase 4: Training & Evaluation
# # Huấn luyện và Đánh giá Mô hình
#
# ## Mục tiêu / Objectives:
# 1. Train all models with 5-fold cross-validation
# 2. Perform hyperparameter tuning with GridSearchCV
# 3. Evaluate classification metrics (Accuracy, Precision, Recall, F1, ROC-AUC)
# 4. Evaluate regression metrics (MSE, RMSE, MAE, R², MAPE)
# 5. Create model comparison table
# 6. Save best models
#
# ---

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import time
import warnings
import sys
import os

from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    classification_report, confusion_matrix, roc_auc_score, roc_curve,
    mean_squared_error, mean_absolute_error, r2_score
)

sys.path.append('../src')

warnings.filterwarnings('ignore')

# Create models directory
os.makedirs('../models', exist_ok=True)

print('Libraries imported successfully!')

# %% [markdown]
# ## 1. Load Data and Prepare Features

# %%
# TODO: Load train and test data
# TODO: Prepare X_train, y_train, X_test, y_test
print('Data loading to be implemented...')

# %% [markdown]
# ## 2. Classification Training
#
# ### 2.1 Train Logistic Regression

# %%
# TODO: Train Logistic Regression with GridSearchCV
# TODO: Evaluate on test set
# TODO: Save model
print('Logistic Regression training to be implemented...')

# %% [markdown]
# ### 2.2 Train Random Forest Classifier

# %%
# TODO: Train Random Forest
print('Random Forest training to be implemented...')

# %% [markdown]
# ### 2.3 Train XGBoost Classifier

# %%
# TODO: Train XGBoost
print('XGBoost training to be implemented...')

# %% [markdown]
# ### 2.4 Train SVM

# %%
# TODO: Train SVM
print('SVM training to be implemented...')

# %% [markdown]
# ### 2.5 Train Neural Network

# %%
# TODO: Train Neural Network
print('Neural Network training to be implemented...')

# %% [markdown]
# ## 3. Classification Results Comparison

# %%
# TODO: Create comparison table
# TODO: Visualize confusion matrices
# TODO: Plot ROC curves
# TODO: Display classification reports
print('Classification comparison to be implemented...')

# %% [markdown]
# ## 4. Regression Training
#
# ### 4.1 Train Linear Regression

# %%
# TODO: Train Linear Regression
print('Linear Regression training to be implemented...')

# %% [markdown]
# ### 4.2 Train Random Forest Regressor

# %%
# TODO: Train Random Forest Regressor
print('Random Forest Regressor training to be implemented...')

# %% [markdown]
# ### 4.3 Train XGBoost Regressor

# %%
# TODO: Train XGBoost Regressor
print('XGBoost Regressor training to be implemented...')

# %% [markdown]
# ### 4.4 Train Gradient Boosting

# %%
# TODO: Train Gradient Boosting
print('Gradient Boosting training to be implemented...')

# %% [markdown]
# ### 4.5 Train Neural Network Regressor

# %%
# TODO: Train Neural Network Regressor
print('Neural Network Regressor training to be implemented...')

# %% [markdown]
# ## 5. Regression Results Comparison

# %%
# TODO: Create comparison table with R², RMSE, MAE, MAPE
# TODO: Plot predicted vs actual
# TODO: Residual analysis
print('Regression comparison to be implemented...')

# %% [markdown]
# ## 6. Save Best Models

# %%
# TODO: Save best classification model
# TODO: Save best regression model
print('Model saving to be implemented...')

# %% [markdown]
# ## 7. Summary

# %%
print('='*80)
print('TRAINING & EVALUATION SUMMARY')
print('='*80)
print('\n✓ All models trained and evaluated!')
print('✓ Best models saved!')
print('\nNext: Proceed to Phase 5 - Visualization')
