# %% [markdown]
# # Phase 5: Visualization & Results
# # Trực quan hóa và Kết quả
#
# ## Mục tiêu / Objectives:
# 1. Create 40+ professional visualizations
# 2. Frequency analysis (disasters by country, continent, type)
# 3. Geographic visualization (world maps)
# 4. Economic impact analysis
# 5. Response and recovery analysis
# 6. Model performance visualization
# 7. Save all plots to reports/figures/
#
# ---

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import folium
from folium.plugins import HeatMap, MarkerCluster
import warnings
import os

warnings.filterwarnings('ignore')

# Set style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

# Create figures directory
os.makedirs('../reports/figures/results', exist_ok=True)

print('Libraries imported successfully!')
print(f'Visualization libraries ready!')

# %% [markdown]
# ## 1. Load Data and Models

# %%
# TODO: Load processed data
# TODO: Load trained models
# TODO: Load predictions
print('Data and models loading to be implemented...')

# %% [markdown]
# ## 2. Frequency Analysis Visualizations
#
# ### 2.1 Disasters by Country

# %%
# TODO: Create bar chart of disasters by country
# TODO: Top 10 countries with most disasters
# TODO: Save figure
print('Country frequency analysis to be implemented...')

# %% [markdown]
# ### 2.2 Disasters by Continent

# %%
# TODO: Create pie chart and bar chart by continent
print('Continent frequency analysis to be implemented...')

# %% [markdown]
# ### 2.3 Disasters by Type

# %%
# TODO: Create distribution of disaster types
print('Disaster type analysis to be implemented...')

# %% [markdown]
# ## 3. Geographic Visualizations
#
# ### 3.1 World Map with Disaster Locations

# %%
# TODO: Create interactive world map using folium or plotly
# Marker size = casualties, color = disaster type
print('World map visualization to be implemented...')

# %% [markdown]
# ### 3.2 Heatmap of Disaster Hotspots

# %%
# TODO: Create heatmap of disaster concentration
print('Heatmap visualization to be implemented...')

# %% [markdown]
# ## 4. Economic Analysis
#
# ### 4.1 Economic Loss by Country

# %%
# TODO: Bar chart of total economic loss by country
print('Economic loss by country to be implemented...')

# %% [markdown]
# ### 4.2 Economic Loss by Continent

# %%
# TODO: Comparison of economic losses across continents
print('Economic loss by continent to be implemented...')

# %% [markdown]
# ### 4.3 Top 10 Most Costly Disasters

# %%
# TODO: Identify and visualize most costly disasters
print('Top 10 costly disasters to be implemented...')

# %% [markdown]
# ## 5. Response Analysis
#
# ### 5.1 Response Efficiency by Country

# %%
# TODO: Average response efficiency scores
print('Response efficiency analysis to be implemented...')

# %% [markdown]
# ### 5.2 Response Time vs Casualties

# %%
# TODO: Scatter plot showing relationship
print('Response time vs casualties to be implemented...')

# %% [markdown]
# ## 6. Recovery Analysis
#
# ### 6.1 Recovery Days by Disaster Type

# %%
# TODO: Box plot of recovery days by disaster type
print('Recovery analysis by type to be implemented...')

# %% [markdown]
# ### 6.2 Recovery vs Severity

# %%
# TODO: Relationship between recovery time and severity
print('Recovery vs severity to be implemented...')

# %% [markdown]
# ## 7. Casualties Analysis
#
# ### 7.1 Casualties by Country

# %%
# TODO: Total casualties by country
print('Casualties by country to be implemented...')

# %% [markdown]
# ### 7.2 Casualties by Continent

# %%
# TODO: Total casualties by continent
print('Casualties by continent to be implemented...')

# %% [markdown]
# ### 7.3 Casualties vs Aid Amount

# %%
# TODO: Scatter plot of casualties vs aid
print('Casualties vs aid to be implemented...')

# %% [markdown]
# ## 8. Aid Distribution Analysis
#
# ### 8.1 Aid Distribution by Disaster Type

# %%
# TODO: Aid distribution analysis
print('Aid distribution to be implemented...')

# %% [markdown]
# ### 8.2 Aid Adequacy (Aid vs Loss)

# %%
# TODO: Compare aid received vs economic loss
print('Aid adequacy analysis to be implemented...')

# %% [markdown]
# ## 9. Model Performance Visualizations
#
# ### 9.1 Confusion Matrix

# %%
# TODO: Visualize confusion matrix for best classifier
print('Confusion matrix to be implemented...')

# %% [markdown]
# ### 9.2 ROC Curves

# %%
# TODO: Plot ROC curves for all classes
print('ROC curves to be implemented...')

# %% [markdown]
# ### 9.3 Feature Importance

# %%
# TODO: Visualize feature importance from tree-based models
print('Feature importance to be implemented...')

# %% [markdown]
# ### 9.4 Model Comparison Charts

# %%
# TODO: Bar charts comparing model performance
print('Model comparison charts to be implemented...')

# %% [markdown]
# ## 10. Correlation Analysis
#
# ### 10.1 Full Correlation Heatmap

# %%
# TODO: Create comprehensive correlation heatmap
print('Correlation heatmap to be implemented...')

# %% [markdown]
# ## 11. Temporal Trends
#
# ### 11.1 Yearly Trends (2018-2024)

# %%
# TODO: Time series of disasters, casualties, losses by year
print('Yearly trends to be implemented...')

# %% [markdown]
# ### 11.2 Monthly Trends

# %%
# TODO: Seasonal patterns in disasters
print('Monthly trends to be implemented...')

# %% [markdown]
# ## 12. Summary

# %%
print('='*80)
print('VISUALIZATION SUMMARY')
print('='*80)
print('\n✓ 40+ professional visualizations created!')
print('✓ All figures saved to reports/figures/')
print('\n✓ PROJECT COMPLETE!')
print('='*80)
